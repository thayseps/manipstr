# %% [markdown]
# <a href="https://colab.research.google.com/github/thayseps/manipstr/blob/main/projeto_final_olympics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Pirando na batatinha')

# %% [markdown]
# Projeto final com os jogos Olimpicos de verão de 2012
# Autora: Thayse Pereira dos Santos
# Data: 12 de fevereiro de 2023

# %%
import pandas as pd

#lendo a planilha
olympics_df = pd.read_excel('olympics7ago.xlsx')

# %%
display(olympics_df.head(10))
# Out:
#   Trigram      Country  Year   Event  Rank             Athlete  Gender Age  \
# 0     AFG  Afghanistan  2012  Summer     1     Nikpai,Rohullah    Male  25
# 1     AFG  Afghanistan  2012  Summer     2        Azizi,Masoud    Male  27
# 2     AFG  Afghanistan  2012  Summer     3  Bahawi,Nesar Ahmad    Male  28
# 3     AFG  Afghanistan  2012  Summer     4        Faisal,Ajmal    Male  21
# 4     AFG  Afghanistan  2012  Summer     5      Faizzada,Ajmal    Male  25
# 5     AFG  Afghanistan  2012  Summer     6   Kohistani,Tahmina  Female  23
# 6     AFG  Afghanistan  2008  Summer     1     Nikpai,Rohullah    Male  21
# 7     AFG  Afghanistan  2008  Summer     2        Azizi,Masoud    Male  23
# 8     AFG  Afghanistan  2008  Summer     3  Bahawi,Nesar Ahmad    Male  24
# 9     AFG  Afghanistan  2008  Summer     4   Yaar,Robina Muqim  Female  22
#
#        Sport  Gold  Silver  Bronze  Total  \
# 0  Taekwondo     0       0       1      1
# 1  Athletics     0       0       0      0
# ...

# %%
print(olympics_df.info)
# Out:
# <bound method DataFrame.info of        Trigram      Country  Year   Event  Rank               Athlete  Gender  \
# 0          AFG  Afghanistan  2012  Summer     1       Nikpai,Rohullah    Male
# 1          AFG  Afghanistan  2012  Summer     2          Azizi,Masoud    Male
# 2          AFG  Afghanistan  2012  Summer     3    Bahawi,Nesar Ahmad    Male
# 3          AFG  Afghanistan  2012  Summer     4          Faisal,Ajmal    Male
# 4          AFG  Afghanistan  2012  Summer     5        Faizzada,Ajmal    Male
# ...        ...          ...   ...     ...   ...                   ...     ...
# 176261     ZIM     Zimbabwe  1964  Summer    27         Unger,Anthony    Male
# 176262     ZIM     Zimbabwe  1964  Summer    28  van Blomestein,Kevin    Male
# 176263     ZIM     Zimbabwe  1964  Summer    29            Wood,Jenny  Female
# 176264     ZIM     Zimbabwe  1928  Summer     1         Bissett,Cecil    Male
# 176265     ZIM     Zimbabwe  1928  Summer     2              Hall,Len    Male
#
# ...

# %%
#só Brasil

brasiltotal_df = olympics_df.loc[olympics_df['Country'] == 'Brazil']
display(brasiltotal_df)
# Out:
#       Trigram Country  Year   Event  Rank                 Athlete  Gender  \
# 16859     BRA  Brazil  2014  Winter     1        Bindilatti,Edson    Male
# 16860     BRA  Brazil  2014  Winter     2            Clark,Isabel  Female
# 16861     BRA  Brazil  2014  Winter     3          da Silva,Sally  Female
# 16862     BRA  Brazil  2014  Winter     4      dos Santos,Fabiana  Female
# 16863     BRA  Brazil  2014  Winter     5         dos Santos,Josi  Female
# ...       ...     ...   ...     ...   ...                     ...     ...
# 19420     BRA  Brazil  1920  Summer    16        Peixoto,Demerval    Male
# 19421     BRA  Brazil  1920  Summer    17        Saliture,Abrahao    Male
# 19422     BRA  Brazil  1920  Summer    18           Veira,Alcides    Male
# 19423     BRA  Brazil  1920  Summer    19        Wellisch,Adolpho    Male
# 19424     BRA  Brazil  1900  Summer     1  Klingelhoeffer,Adolphe    Male
#
#         Age             Sport  Gold  Silver  Bronze  Total  \
# ...

# %%
#só atletas do vôlei
voleibr_df = brasiltotal_df.loc[brasiltotal_df['Sport'] == 'Volleyball']
display(voleibr_df)
# Out:
#       Trigram Country  Year   Event  Rank              Athlete  Gender Age  \
# 16872     BRA  Brazil  2012  Summer     1             Adenizia  Female  25
# 16873     BRA  Brazil  2012  Summer     2                 Fabi  Female  32
# 16874     BRA  Brazil  2012  Summer     3              Fabiana  Female  27
# 16875     BRA  Brazil  2012  Summer     4          Fernandinha  Female  32
# 16876     BRA  Brazil  2012  Summer     5       Garay,Fernanda  Female  26
# ...       ...     ...   ...     ...   ...                  ...     ...  ..
# 18949     BRA  Brazil  1964  Summer    36          Franca,Joao    Male  21
# 18957     BRA  Brazil  1964  Summer    44       Newdon,Emanuel    Male  26
# 18959     BRA  Brazil  1964  Summer    46        Nuzman,Carlos    Male  22
# 18963     BRA  Brazil  1964  Summer    50         Ramalho,Jose    Male  27
# 18970     BRA  Brazil  1964  Summer    57  Volpi,Marco Antonio    Male  21
#
#             Sport  Gold  Silver  Bronze  Total  \
# ...

# %%
#time fem
voleifem_df = voleibr_df.loc[voleibr_df['Gender'] == 'Female']
display(voleifem_df.head(14))
# Out:
#       Trigram Country  Year   Event  Rank         Athlete  Gender Age  \
# 16872     BRA  Brazil  2012  Summer     1        Adenizia  Female  25
# 16873     BRA  Brazil  2012  Summer     2            Fabi  Female  32
# 16874     BRA  Brazil  2012  Summer     3         Fabiana  Female  27
# 16875     BRA  Brazil  2012  Summer     4     Fernandinha  Female  32
# 16876     BRA  Brazil  2012  Summer     5  Garay,Fernanda  Female  26
# 16877     BRA  Brazil  2012  Summer     6           Jaque  Female  28
# 16878     BRA  Brazil  2012  Summer     7       Lins,Dani  Female  27
# 16880     BRA  Brazil  2012  Summer     9         Natalia  Female  23
# 16881     BRA  Brazil  2012  Summer    10           Paula  Female  30
# 16882     BRA  Brazil  2012  Summer    11         Sheilla  Female  29
# 16883     BRA  Brazil  2012  Summer    12         Tandara  Female  23
# 16884     BRA  Brazil  2012  Summer    13          Thaisa  Female  25
# ...

# %%
#time masc
voleimasc_df = voleibr_df.loc[voleibr_df['Gender'] == 'Male']
display(voleimasc_df.head(14))
# Out:
#       Trigram Country  Year   Event  Rank         Athlete Gender Age  \
# 16888     BRA  Brazil  2012  Summer    17    Alves,Thiago   Male  25
# 16889     BRA  Brazil  2012  Summer    18        Bruninho   Male  26
# 16893     BRA  Brazil  2012  Summer    22           Dante   Male  31
# 16895     BRA  Brazil  2012  Summer    24       Escadinha   Male  36
# 16899     BRA  Brazil  2012  Summer    28            Giba   Male  35
# 16904     BRA  Brazil  2012  Summer    33          Murilo   Male  31
# 16906     BRA  Brazil  2012  Summer    35   Neves,Leandro   Male  29
# 16911     BRA  Brazil  2012  Summer    40      Ricardinho   Male  36
# 16912     BRA  Brazil  2012  Summer    41        Rodrigao   Male  33
# 16914     BRA  Brazil  2012  Summer    43  Saatkamp,Lucas   Male  26
# 16916     BRA  Brazil  2012  Summer    45           Sidao   Male  30
# 16919     BRA  Brazil  2012  Summer    48         Wallace   Male  25
# 17139     BRA  Brazil  2008  Summer    15        Anderson   Male  34
# ...
